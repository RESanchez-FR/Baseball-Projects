# %%
from pybaseball import playerid_lookup
from pybaseball import batting_stats 
from Functions import predict_home_runs, add_player_specific_features
from Home_Run_Predictor_Class import HomeRunPredictor
import pandas as pd

# %%
data = batting_stats(2014, 2024)

# %%
pd.set_option('display.max_columns', None)
data.head()
# Out:
#      IDfg  Season            Name Team  Age    G   AB   PA    H   1B  2B  3B  \
# 1   15640    2024     Aaron Judge  NYY   32  158  559  704  180   85  36   1
# 3   15640    2022     Aaron Judge  NYY   30  157  570  696  177   87  28   0
# 51  25764    2024  Bobby Witt Jr.  KCR   24  161  636  709  211  123  45  11
# 5   13611    2018    Mookie Betts  BOS   25  136  520  614  180   96  47   5
# 6   10155    2018      Mike Trout  LAA   26  140  471  608  147   80  24   4
#
#     HR    R  RBI   BB  IBB   SO  HBP  SF  SH  GDP  SB  CS    AVG   GB   FB  \
# 1   58  122  144  133   20  171    9   2   0   22  10   0  0.322  119  180
# 3   62  133  131  111   19  175    6   5   0   14  16   3  0.311  149  174
# 51  32  125  109   57    9  106    8   8   0    4  31  12  0.332  199  239
# 5   32  129   80   81    8   91    8   5   0    5  30   6  0.346  147  195
# 6   39  101   79  122   25  124   10   4   0    5  24   2  0.312  110  159
#
# ...

# %%
# Call the function
results = predict_home_runs(data)
# Out:
# Model: Ridge
# Mean Squared Error: 8.890951788386754
# R-squared Score: 0.9163854557139269
#
# Model: Lasso
# Mean Squared Error: 44.06808678540018
# R-squared Score: 0.585563718956017
#
# Model: ElasticNet
# Mean Squared Error: 44.027868544085145
# R-squared Score: 0.5859419495436506
#
# Model: RandomForest
# Mean Squared Error: 3.8217895081967215
# R-squared Score: 0.9640581575863941
#
# Selected ElasticNet as the best model.
# Best Model: ElasticNet
# Best MSE: 44.027868544085145
#
# Predicted Home Run Leaderboard for Next Season (2025):
#                      Name   Team  HR  Projected_HR  Difference
# 0             Aaron Judge    NYY  58          50.0        -8.0
# 1           Shohei Ohtani    LAD  54          43.0       -11.0
# 2          Bobby Witt Jr.    KCR  32          39.0         7.0
# 3          Yordan Alvarez    HOU  35          38.0         3.0
# 4            Brent Rooker    OAK  39          38.0        -1.0
# ...
