# %%
###Running the Pitvher Class

from Pitching_Deception import Pitching_Deception_Calc

# %%
if __name__ == "__main__":
    analyzer = Pitching_Deception_Calc()
    
    # Example usage:
    player_name_list = ['Skubal Tarik', 'Wheeler Zack', 'Sale Chris', 'Lugo Seth', 'Skenes Paul']
    start_date = '2024-03-28'
    end_date = '2024-10-06'
    
    analyzer.retrieve_and_save_data(player_name_list, start_date, end_date)
    analyzer.run_analysis()
# Out:
# Gathering player lookup table. This may take a moment.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 9
#       6 start_date = '2024-03-28'
#       7 end_date = '2024-10-06'
# ----> 9 analyzer.retrieve_and_save_data(player_name_list, start_date, end_date)
#      10 analyzer.run_analysis()
#
# File c:\Users\ramon\Desktop\Projects\Career\Texas_Rangers\Pitching_Deception.py:25, in Pitching_Deception_Calc.retrieve_and_save_data(self, player_name_list, start_date, end_date)
#      23 last_name, first_name = player.split()
#      24 try:
# ---> 25     player_id = playerid_lookup(last_name, first_name)['key_mlbam'].iloc[0]
#      26     data = statcast_pitcher(start_dt=start_date, end_dt=end_date, player_id=player_id)
#      27     if not data.empty:
#
# ...
